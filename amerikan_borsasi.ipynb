# %% [markdown]
# <a href="https://colab.research.google.com/github/ozgur67/python_/blob/main/amerikan_borsasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/rongardF/tvdatafeed tradingview-screener
import numpy as np
import pandas as pd
from tvDatafeed import TvDatafeed, Interval
from tradingview_screener import get_all_symbols
import warnings

warnings.simplefilter(action='ignore')

# Standart Moving Average
def sma(series, length):
    """
    Calculate the Simple Moving Average (SMA) for a given series.
    """
    return series.rolling(window=length).mean()

# Exponential Moving Average
def ema(series, length):
    """
    Calculate the Exponential Moving Average (EMA) for a given series.
    """
    return series.ewm(span=length, adjust=False).mean()

def Bankery(data):
    df = data.copy()
    close_minus_rolling_min = data['close'] - pd.Series(data['low']).rolling(window=27).min()
    percentage_change = close_minus_rolling_min / (pd.Series(data['high']).rolling(window=27).max() - pd.Series(data['low']).rolling(window=27).min()) * 100

    sma1 = sma(percentage_change, 5)
    sma2 = sma(sma1, 3)

    fundtrend = (3 * sma1 - 2 * sma2 - 50) * 1.032 + 50

    typ = (2 * data['close'] + data['high'] + data['low'] + data['open']) / 5
    lol = pd.Series(data['low']).rolling(window=34).min()
    hoh = pd.Series(data['high']).rolling(window=34).max()
    bullbearline = ema((typ - lol) / (hoh - lol) * 100, 13)
    bankerentry = (fundtrend > bullbearline) & (bullbearline < 25)
    df['Entry'] = (bankerentry == True)
    return df

# TradingView verisini çekme
tv = TvDatafeed(username='your_username', password='your_password')
nasdaq_symbols = get_all_symbols(market='america')[:500]
nasdaq_symbols = [symbol.replace('NASDAQ:', '') for symbol in nasdaq_symbols]

# Raporlama için kullanılacak başlıklar
Titles = ['Hisse Adı', 'Son Fiyat', 'Dip Sinyali']
df_signals = pd.DataFrame(columns=Titles)

for symbol in nasdaq_symbols:
    try:
        data = tv.get_hist(symbol=symbol, exchange='NASDAQ', interval=Interval.in_daily, n_bars=100)
        data = data.reset_index()
        Banker = Bankery(data)
        Banker.rename(columns={'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'volume': 'Volume'}, inplace=True)
        Banker.set_index('datetime', inplace=True)
        Buy = False
        Signals = Banker.tail(2)
        Signals = Signals.reset_index()

        Entry = (Signals.loc[0, 'Entry'] == False) & (Signals.loc[1, 'Entry'] == True)
        Last_Price = Signals.loc[1, 'Close']
        L1 = [symbol, Last_Price, Entry]
        df_signals.loc[len(df_signals)] = L1
        print(L1)
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")

df_True = df_signals[(df_signals['Dip Sinyali'] == True)]
print(df_True)
# Out:
# Collecting git+https://github.com/rongardF/tvdatafeed
#   Cloning https://github.com/rongardF/tvdatafeed to /tmp/pip-req-build-1vdu9cmf
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed /tmp/pip-req-build-1vdu9cmf
#   Resolved https://github.com/rongardF/tvdatafeed to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# Collecting tradingview-screener
#   Downloading tradingview_screener-2.5.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 659.0 kB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (67.7.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.0.3)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.31.0)
# Collecting pandas (from tvdatafeed==2.1.0)
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->tvdatafeed==2.1.0) (1.16.0)
# Building wheels for collected packages: tvdatafeed
#   Building wheel for tvdatafeed (setup.py) ... done
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17533 sha256=8b45f005f85924d8ef6d033e2ee36f8568623b43738efbab2a0593c81437d83a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8ns72a6t/wheels/e4/32/1e/21ebcacc6549d75fae3bf3ff75cee8fcbe4e5c189d88fbd5a1
# Successfully built tvdatafeed
# Installing collected packages: pandas, tvdatafeed, tradingview-screener
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.2.2 which is incompatible.
# Successfully installed pandas-2.2.2 tradingview-screener-2.5.0 tvdatafeed-2.1.0
# ERROR:tvDatafeed.main:error while signin
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# ['AMEX:PLAG', 1.485, False]
# ['OTC:KDDIY', 13.06, False]
# ['OTC:AREVF', 0.028, False]
# ['AMEX:CARY', 20.69, False]
# ['AMEX:TMFG', 29.43, False]
# ['OTC:SKLTY', 28.65, False]
# ['ABEO', 4.07, False]
# ['AMEX:GBLD', 15.6376, False]
# ['AMEX:KOMP', 45.88, False]
# ['FFIE', 0.427, False]
# ['CALC', 4.45, False]
# ['JSMD', 66.08, False]
# ['OTC:BESVF', 173.82, False]
# ['AMEX:AFIF', 9.11, False]
# ['NYSE:IAE', 6.32, False]
# ['OTC:NDCVF', 13.0, False]
# ['TMC', 1.39, False]
# ['AMEX:AULT/PD', 26.6, False]
# ['EMB', 88.975, False]
# ['OTC:WBRBY', 6.56, False]
# ['AMEX:CEI', 0.116554, False]
# ['OTC:MCEM', 193.7327, False]
# ['OTC:PRLPF', 16.83, False]
# ['OTC:MMTLF', 0.17535, False]
# ['SLNA', 0.0791, False]
# ['OTC:STQN', 0.341, False]
# ['OTC:TUIFF', 7.11, False]
# ['OTC:ADYYF', 1229.815, False]
# ['CVGI', 5.02, False]
# ['OTC:BRSE', 0.06, False]
# ['OTC:WRLC', 551.25, False]
# ['OTC:CJREF', 0.1, False]
# ['OTC:GWTR', 0.02, False]
# ['OTC:LTHCF', 0.3925, False]
# ['QQQA', 46.2146, False]
# ['NVDS', 39.7, False]
# ['AMEX:PALC', 48.73, False]
# ['OTC:CVPUF', 1.53, False]
# ['OTC:PRXXF', 12.5, False]
# ['AMEX:PAVE', 36.82, False]
# ['OTC:BAESY', 67.16, False]
# ['OTC:SOAGY', 47.47, False]
# ['AMEX:SDEM', 25.71, False]
# ['MNDO', 1.8799, False]
# ['VC', 104.88, False]
# ['OTC:VULMF', 0.085, False]
# ['OTC:GPPRF', 0.08, False]
# ['OTC:GLNLF', 0.0982, False]
# ['AMEX:CMCI', 25.559, False]
# ['OTC:PGCSF', 1.94, False]
# ['FCEF', 20.83, False]
# ['BECN', 89.03, False]
# ['OTC:CLOEF', 2.1, False]
# ['OTC:HLAGF', 180.42, False]
# ['OTC:BKISF', 4.0418, False]
# ['OTC:SSEBF', 0.0119, True]
# ['AMEX:EUM', 13.45, False]
# ['AMEX:DJUL', 39.772, False]
# ['WINC', 23.86, False]
# ['NYSE:APLE', 14.245, False]
# ['OTC:QCXGF', 0.005, False]
# ['AMEX:BRN', 2.38, False]
# ['STRR', 4.01, False]
# ['NYSE:EPR/PC', 19.3199, False]
# ['KVAC', 10.58, False]
# ['AMEX:APRJ', 24.88, False]
# ['OTC:CMGO', 0.002, False]
# ['CVLY', 22.42, False]
# ['ARAY', 1.75, False]
# ['NYSE:AHH/PA', 21.57, False]
# ['OTC:FZRO', 0.54, False]
# ['OTC:WCUI', 0.0006, False]
# ['OTC:BUDZ', 0.069, False]
# ['OTC:RKMSF', 0.0133, False]
# ['AMEX:IWIN', 26.68, False]
# ['VTNR', 1.03, False]
# ['NYSE:CCM', 0.76, False]
# ['NYSE:PDT', 11.385, False]
# ['POWI', 69.8, False]
# ['AMEX:BCIL', 25.4967, False]
# ['OTC:YORKF', 0.055, False]
# ['OTC:FXLG', 29.54, False]
# ['OTC:FINMY', 11.5099, False]
# ['AMEX:SMDV', 60.85, False]
# ['OTC:INIKF', 0.08, False]
# ['OTC:XNYIF', 0.5491, False]
# ['NYSE:OTIS', 95.45, False]
# ['AMEX:SEPZ', 37.353, False]
# ['OTC:PMAH', 1e-06, False]
# ['CAAS', 3.71, False]
# ['OTC:NEXHY', 11.06, False]
# ['ASUR', 8.2, False]
# ['AMEX:HNRA', 2.525, False]
# ['OTC:VYND', 0.42825, False]
# ['AMEX:FLOW', 30.04, False]
# ['NYSE:SLG/PI', 20.94, False]
# ['NYSE:AEE', 69.92, False]
# ['NAAS', 3.46, False]
# ['AMEX:BECO', 20.85, False]
# ['AMEX:QTAP', 34.78, False]
# ['OTC:BLFR', 0.24, False]
# ['AKLI', 0.431949, False]
# ['ASPI', 3.2, False]
# ['OTC:BBSEY', 5.948, False]
# ['AMEX:INCE', 54.1699, False]
# ['NYSE:YELP', 36.87, False]
# ['KURA', 20.61, False]
# ['OTC:RGLSF', 1.49, False]
# ['SVCO', 17.64, False]
# ['VEV', 0.57, False]
# ['OTC:FTMDF', 0.0661, False]
# ['GTR', 23.79, False]
# ['OTC:NVLHF', 0.0946, False]
# ['VSME', 1.88, False]
# ['NYSE:BME', 40.2, False]
# ['NYSE:HUM', 360.08, False]
# ['OSIS', 136.34, False]
# ['OTC:IINX', 1e-06, False]
# ['AFCG', 11.58, False]
# ['AMEX:FTEC', 170.42, False]
# ['AMEX:BGI', 2.505, False]
# ['OTC:COGNY', 0.36, False]
# ['OTC:ADXS', 0.25, False]
# ['NYSE:RSKD', 6.36, False]
# ['AMEX:SPXV', 58.26, False]
# ['OTC:NESRF', 8.685, False]
# ['NYSE:UHT', 38.23, False]
# ['IPXX', 10.6, False]
# ['OTC:DINRF', 94.815, False]
# ['OTC:CANOF', 0.295, False]
# ['OTC:BWMY', 0.0225, False]
# ['OTC:NPPXF', 0.9009, False]
# ['OTC:CETI', 0.3, False]
# ['AMEX:BFIX', 23.3302, False]
# ['ONBPO', 24.95, False]
# ['OTC:KROEF', 0.805, False]
# ['JFIN', 6.22, False]
# ['PUI', 34.6583, False]
# ['OTC:BAUFF', 0.075, False]
# ['OTC:EVKIF', 19.35, False]
# ['OTC:LNMG', 0.24, True]
# ['OTC:XOEEF', 0.2172, False]
# ['OTC:LWSCF', 10.4, False]
# ['ACST', 3.02, False]
# ['NYSE:IGT', 19.995, False]
# ['OTC:UNVGY', 15.01, False]
# ['OTC:BBVXF', 10.05, False]
# ['OTC:FFRMF', 1e-06, False]
# ['AMEX:THNR', 26.05, False]
# ['BLNK', 2.685, False]
# ['OTC:FNMAS', 4.7525, False]
# ['NYSE:BRX', 22.31, False]
# ['AMEX:OFOS', 28.1059, False]
# ['AMEX:EV', 23.3574, False]
# ['NYSE:GDL/PC', 49.49, False]
# ['TBLA', 3.4, False]
# ['OTC:PMMAF', 45.39, False]
# ['NYSE:PHT', 7.449, False]
# ['AMEX:BRZU', 61.97, False]
# ['OTC:AJOY', 0.0352, False]
# ['MODD', 1.57, False]
# ['OTC:ARBV', 16.6, False]
# ['NYSE:AGM.A', 123.48, False]
# ['DUOT', 2.69, False]
# ['OTC:PPBN', 27.5, False]
# ['TOP', 2.42, False]
# ['AMEX:PCIG', 9.6, False]
# ['AMEX:XTNT', 0.6212, False]
# ['OTC:AINMF', 0.2215, False]
# ['AMEX:UCC', 36.3101, False]
# ['AMEX:YMAG', 20.82, False]
# ['VONV', 76.779, False]
# ['CALB', 20.1, False]
# ['TSLA', 196.5, False]
# ['NYSE:KB', 55.86, False]
# ['OTC:RCAR', 0.0001, False]
# ['OTC:WNLV', 1.197, False]
# ['TRIB', 2.04, False]
# ['BCAL', 12.82, False]
# ['AMEX:PSFF', 27.766, False]
# ['OTC:LONCF', 0.26, False]
# ['IFRX', 1.5899, False]
# ['OTC:MICRD', 0.5227, False]
# ['NTRP', 1.995, False]
# ['ABTS', 0.5001, False]
# ['OPI', 2.11, False]
# ['NYSE:MFAO', 25.4, False]
# ['OTC:SCGPY', 2.28, False]
# ['WISE', 27.66, False]
# ['AMEX:NTIP', 1.59, False]
# ['AMEX:EDOW', 33.9565, False]
# ['NFTY', 59.72, False]
# ['AMEX:OCTW', 34.4992, False]
# ['OTC:GCHK', 0.0002, False]
# ['OTC:FSPKF', 18.25, False]
# ['OTC:DIGP', 0.0191, False]
# ['OTC:COSG', 1e-06, False]
# ['AMEX:IDEV', 65.48, False]
# ['OTC:DTSRF', 4.6, False]
# ['OTC:APTPF', 1.6, False]
# ['WAFD', 26.76, False]
# ['AMEX:CALF', 43.19, False]
# ['AMEX:RSPN', 45.3879, False]
# ['NYSE:SNAP', 16.76, False]
# ['OTC:RHCGF', 2.1, False]
# ['OTC:STMZF', 11.244, False]
# ['OTC:NKGFF', 0.205, False]
# ['SBLK', 24.62, False]
# ['SPPL', 0.5735, False]
# ['OTC:SALRY', 13.33, False]
# ['TXRH', 171.29, False]
# ['OTC:MCHVY', 20.2, False]
# ['AMEX:MJUS', 1.73, False]
# ['OTC:PREC', 0.005, False]
# ['AMEX:TILT', 199.28, False]
# ['OTC:ONEXF', 68.99, False]
# ['OTC:OILY', 1e-06, False]
# ['BOCNU', 11.88, False]
# ['OTC:KAIKY', 14.2, False]
# ['AMEX:BAUG', 40.54, False]
# ['OTC:TRUMY', 16.17, False]
# ['AMEX:CLDI', 0.19, False]
# Error fetching data for NYSE:STXI: 1
# ['PROF', 8.95, False]
# ['TEM', 27.3, False]
# ['OTC:IVSRF', 5.95, False]
# ['NYSE:SXC', 9.47, False]
# ['OTC:ENEAY', 9.42, False]
# ['BGC', 8.07, False]
# ['BWAY', 6.16, False]
# ['OTC:IGBSF', 8.26, False]
# ['AMEX:GURU', 43.23, False]
# ['OTC:BOMO', 0.00441, False]
# ['OTC:GHST', 0.0411, False]
# ['MGIC', 9.9891, True]
# ['OTC:DSDVF', 154.16, False]
# ['OTC:QBIO', 1e-06, False]
# ['DWAS', 83.7, False]
# ['OTC:CMGMF', 5.03, False]
# ['OTC:HMMR', 0.39, False]
# ['OTC:MDDVF', 0.2918, False]
# ['OTC:REMRF', 0.414, False]
# ['AAPU', 33.4, False]
# ['OTC:RCRUY', 10.453, False]
# ['OTC:DTCFF', 0.5723, False]
# ['OTC:CWXZF', 5.158, False]
# ['OTC:TOLWF', 3.41, False]
# ['OTC:CVAT', 0.009, False]
# ['AMEX:IOPP', 27.8099, False]
# ['OTC:SFIO', 0.002, False]
# ['OTC:DEWM', 1e-06, False]
# ['UCBI', 24.92, False]
# ['NYSE:PNM', 36.53, False]
# ['NYSE:JPM/PM', 19.27, False]
# ['NYSE:HCXY', 24.79, False]
# ['OTC:MBLU', 18.55, False]
# ['AMEX:STPZ', 51.545, False]
# ['OTC:FBDS', 0.04, True]
# ['OTC:HYPRF', 0.953, False]
# ['OTC:ENDRF', 0.389, False]
# ['AMEX:NRGU', 491.47, False]
# ['OST', 0.4279, True]
# ['NYSE:AMPX', 1.23, False]
# ['OTC:STOSF', 4.76, False]
# ['NYSE:HQH', 17.31, False]
# ['OTC:LDNXF', 119.5, False]
# ['AMEX:DUBS', 30.57, False]
# ['AMEX:JULT', 36.98, False]
# ['OTC:SPNRF', 0.0071, False]
# ['OTC:KNNGF', 39.11, False]
# ['AMEX:SCHZ', 45.705, False]
# ['OTC:IVCGF', 11.2535, False]
# ['AMEX:KSEA', 26.32, False]
# ['NYSE:EFC/PB', 21.77, False]
# ['OTC:CNLTN', 32.1313, False]
# ['STNE', 11.75, False]
# ['OTC:VAYK', 0.001, False]
# ['OTC:KIROY', 7.87, False]
# ['NYSE:GHLD', 14.89, False]
# ['NYSE:RIV', 12.15, False]
# ['NXL', 2.69, False]
# ['OTC:WARM', 0.0011, False]
# ['DKNG', 37.45, False]
# ['AMEX:JHMD', 33.0812, False]
# ['OTC:ECDP', 0.096, False]
# ['VRPX', 0.5115, False]
# ['AMEX:CONY', 19.57, False]
# ['POCI', 5.6501, False]
# ['NYSE:WTRG', 37.23, False]
# ['NYSE:KFRC', 62.18, False]
# ['WBUY', 0.1669, False]
# ['NYSE:AA', 39.0, False]
# ['NYSE:TRTX', 8.63, False]
# ['CMPO', 6.37, False]
# ['OTC:UUGRY', 25.3064, False]
# ['PCSA', 2.05, False]
# ['NYSE:SBSW', 4.33, False]
# ['DCOM', 19.19, False]
# ['AMEX:FCOR', 46.35, False]
# ['OTC:DCAC', 1e-06, False]
# ['OTC:IPOOF', 1.625, False]
# ['AMEX:VUSB', 49.48, False]
# ['SEVN', 12.5001, False]
# ['MGTX', 4.17, False]
# ['OTC:BCHEY', 21.4046, False]
# ['AMEX:WANT', 33.64, False]
# ['OTC:UOVEF', 22.72, False]
# ['OTC:CJPRY', 10.6, False]
# ['OTC:ORXOY', 2.0, False]
# ['OTC:AHNR', 0.04, False]
# ['OTC:NWARF', 1.15, False]
# ['AMEX:IBUY', 54.99, False]
# ['AMEX:QULL', 46.1763, False]
# ['OTC:SETO', 0.0222, False]
# ['LSBK', 12.65, False]
# ['XFOR', 1.0, False]
# ['AMEX:HYGH', 85.16, False]
# ['AMEX:CPII', 19.46, False]
# ['AMEX:NEN', 70.58, False]
# ['NYSE:AHL/PE', 19.5879, False]
# ['OTC:CBUMY', 17.93, False]
# ['OTC:TLRS', 0.0873, False]
# ['OTC:PGEZF', 0.1145, False]
# ['OTC:SFFYF', 26.0, False]
# ['OTC:UJOGF', 0.23, False]
# ['NYSE:JHX', 31.65, False]
# ['AMEX:IG', 20.525, False]
# ['AMEX:CRDT', 24.74, False]
# ['NYSE:PAAS', 20.01, False]
# ['OTC:CVSC', 0.0001, False]
# ['NYSE:BC', 71.22, False]
# ['OTC:IICN', 0.018, False]
# ['NYSE:KN', 16.98, False]
# ['OTC:CHUC', 0.17, False]
# ['AMEX:FXI', 26.505, False]
# ['OTC:TORVF', 0.024, False]
# ['OTC:PEMIF', 0.28, False]
# ['OTC:CPFXF', 0.1895, False]
# ['NYSE:DLB', 78.64, False]
# ['BSCO', 21.05, False]
# ['AMEX:PRAE', 32.8526, False]
# ['OTC:ASKH', 0.029, False]
# ['OTC:SFBE', 0.0004, False]
# ['NYSE:IDE', 10.2051, False]
# ['OTC:ALTPF', 0.07, False]
# ['CAC', 31.71, False]
# ['OTC:MLLOF', 0.085, False]
# ['AMEX:JANJ', 24.98, False]
# ['AIPI', 53.85, False]
# ['CHY', 11.045, False]
# ['OTC:FSUMF', 14.2, False]
# ['OTC:KNBHF', 75.405, False]
# ['NYSE:FBP', 17.885, False]
# ['OTC:GOAI', 2.9437, False]
# ['OTC:ACKDF', 4.645, False]
# ['OTC:IGPK', 0.0075, False]
# ['BNAI', 3.06, False]
# ['OTC:WWRL', 0.0051, False]
# ['OTC:KLNG', 0.82, False]
# ['OTC:BGLAF', 11.75, False]
# ['OTC:OWRDF', 0.02, False]
# ['OTC:SINC', 0.0042, False]
# ['BIOR', 0.6396, False]
# ['OTC:JPPHY', 9.36, False]
# ['VRM', 9.26, False]
# ['OTC:RSAU', 0.644152, False]
# ['NYSE:SQ', 63.35, False]
# ['XRTX', 1.9604, False]
# ['INO', 7.82, False]
# ['NYSE:DAC', 93.75, False]
# ['OTC:LOGL', 1e-06, False]
# ['AMEX:PCRB', 48.19, False]
# ['CLOV', 1.29, False]
# ['NYSE:ELME', 15.415, False]
# ['OTC:AGGZF', 36.13, False]
# ['OTC:SLRRF', 0.055, False]
# ['AMEX:SIF', 2.99, False]
# ['OTC:PTVRF', 1.0, False]
# ['OTC:SNGCF', 0.054, False]
# ['WTMA', 11.09, False]
# ['NYSE:SNDR', 23.435, False]
# ['GEOS', 9.05, True]
# ['AMEX:NETL', 22.8583, False]
# ['AMEX:RINF', 32.68, False]
# ['OTC:PNNX', 0.0375, False]
# ['PLAO', 11.44, False]
# ['OTC:LANRF', 0.0182, False]
# ['NYSE:ZUO', 9.195, False]
# ['OTC:GTHP', 0.1111, False]
# ['AMEX:GOAU', 18.805, False]
# ['OTC:UEPEO', 73.5, False]
# ['OTC:TMXXF', 27.72, False]
# ['AMEX:OVT', 22.12, False]
# ['AMEX:CNDA.U', 10.8, False]
# ['NYSE:BSBR', 5.005, False]
# ['EDIT', 4.815, False]
# ['AMEX:SCIO', 20.3155, False]
# ['NYSE:MC', 53.35, False]
# ['AMEX:PALL', 85.8063, False]
# ['OTC:SSHPF', 0.61, False]
# ['OTC:VOPKY', 40.5, False]
# ['OTC:INPAP', 66.92, False]
# ['OTC:HTCMY', 52.94, False]
# ['OTC:RINO', 0.0002, False]
# ['AMEX:RAYJ', 24.72, False]
# ['NYSE:CXT', 60.43, False]
# ['OTC:CSTPF', 0.32, False]
# ['OTC:MGPPF', 7.22, False]
# ['SWVL', 6.55, False]
# ['AKAM', 88.2, False]
# ['OTC:IUQFF', 14.16, False]
# ['OTC:RWNFF', 36.0655, False]
# ['NYSE:BAC', 38.94, False]
# ['AMEX:RVNU', 25.63, False]
# ['AMEX:PIT', 49.55, False]
# ['OTC:ISCXF', 5.7672, False]
# ['LAMR', 116.52, False]
# ['OTC:LQWC', 0.012, False]
# ['OTC:RGUS', 0.0028, False]
# ['OTC:TCLHF', 0.8465, False]
# ['AMEX:ATFV', 21.295, False]
# ['OTC:SZKMF', 11.356, False]
# ['OTC:EVOTF', 8.98, False]
# ['AMEX:BTG', 2.625, False]
# ['NYSE:GSL', 29.54, False]
# ['OTC:TATYF', 8.0, False]
# ['OTC:SNNF', 6.95, False]
# ['FNCB', 6.11, False]
# ['OTC:SNLAF', 0.9214, False]
# ['OTC:CTXAY', 42.89, False]
# ['WABF', 25.535, False]
# ['NYSE:RFMZ', 14.04, False]
# ['UCAR', 7.94, False]
# ['OTC:ACFN', 9.75, False]
# ['OTC:GXLM', 31.0, False]
# ['AMEX:ITDH', 30.0375, False]
# ['BGLC', 0.481, False]
# ['NYSE:DSU', 10.765, False]
# ['EXAI', 5.25, False]
# ['ZYME', 8.41, False]
# ['AMEX:ATNM', 7.325, False]
# ['OTC:SKHSY', 21.75, False]
# ['CITE', 11.34, False]
# ['KA', 0.5513, False]
# ['NYSE:MYTE', 4.92, False]
# ['VONG', 94.1, False]
# ['OTC:GOCOF', 0.035, False]
# ['CFFI', 51.88, False]
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# Error fetching data for OTC:AUMMF: 'NoneType' object has no attribute 'reset_index'
# ['OTC:CSSI', 0.025, False]
# ['OTC:SRCGF', 0.0331, False]
# ['OTC:PMCCF', 0.085, False]
# ['OTC:ETRUF', 0.1071, False]
# ['WHLRP', 2.1189, False]
# ['OTC:AUXIF', 0.0288, False]
# ['OTC:ALST', 0.00065, False]
# ['IVEG', 18.8591, False]
# ['AMEX:PHB', 18.0, False]
# ['STKH', 3.5, False]
# ['OTC:MHCUF', 14.03, False]
# ['OTC:INBP', 0.2, False]
# ['VREX', 14.43, False]
# ['NYSE:ET/PI', 11.235, False]
# ['NYSE:GDV/PH', 22.98, False]
# ['OTC:KYYWF', 28.0, False]
# ['NYSE:HAE', 82.56, False]
# ['AMEX:PFUT', 24.43, False]
# ['OTC:AIBGY', 10.61, False]
# ['OTC:TLCC', 0.015, False]
# ['WHLM', 5.27, False]
# ['CNSP', 1.87, False]
# ['OTC:MKTAY', 26.98, False]
# ['NYSE:BHLB', 21.72, False]
# ['AMEX:CGRO', 20.6421, False]
# ['OTC:MYBUF', 0.009, False]
# ['QQQE', 88.61, False]
# ['PABU', 59.45, False]
# ['FLXS', 30.8, False]
# ['BMBL', 10.14, False]
# ['OTC:SINGF', 4.9, False]
# ['AMEX:GSG', 22.11, False]
# ['NYSE:CNC', 67.6, False]
# ['OTC:BCAP', 0.0001, False]
# ['AMEX:PSCX', 26.3835, False]
# ['AMEX:JPME', 94.71, False]
# ['AMEX:PPI', 14.81, False]
# ['OTC:CVWFF', 0.6275, False]
# ['NMFC', 12.135, False]
# ['OTC:COBA', 1.25, False]
# ['PNFPP', 23.412, False]
# ['NYSE:STEW', 14.4801, False]
# ['DHC', 2.675, False]
# ['AMEX:ACIO', 37.76, False]
# ['USCB', 12.24, False]
# ['AMEX:ESUS', 29.7513, False]
# ['DGICB', 11.25, False]
# ['AMEX:BEMB', 52.0963, False]
# ['AMEX:PTL', 197.29, False]
# ['AMEX:JHID', 28.5696, False]
# ['AMEX:PW/PA', 2.82, False]
#      Hisse Adı  Son Fiyat  Dip Sinyali
# 55   OTC:SSEBF     0.0119         True
# 140   OTC:LNMG     0.2400         True
# 233       MGIC     9.9891         True
# 256   OTC:FBDS     0.0400         True
# 260        OST     0.4279         True
# 380       GEOS     9.0500         True
